# %%
from ultralytics import YOLO

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# Cargar el modelo desde la arquitectura YAML sin pesos preentrenados
model = YOLO('yolov8m.yaml')  # o la ruta local a tu YAML

# Entrenar desde cero
model.train(
    data='./Dataset/detection/data.yaml',       # Ruta a tu archivo YAML con clases y rutas
    epochs=20,
    imgsz=(640, 1152),
    batch=4,
    device=0             # GPU = 0, CPU = 'cpu'
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.162 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.159 🚀 Python-3.12.11 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6057MiB)
# ...
