# %%
image = "dataset_engineering/active_learning/object_detection/fine_tuning/train/images/20250710_144746_0a23fc.jpg"
label = "dataset_engineering/active_learning/object_detection/fine_tuning/train/labels/20250710_144746_0a23fc.txt"

# %%
import importlib
from media_tools import image_tools
importlib.reload(image_tools)

annotated_image = image_tools.annotate_image(image,label,stylized=False)
image_tools.display_image(annotated_image,figsize=(11,10))

# %%
import cv2
img = cv2.imread(image)
print(type(img))
# Out:
# <class 'numpy.ndarray'>
