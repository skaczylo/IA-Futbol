# %% [markdown]
# # Label Studio Object Detection

# %% [markdown]
# ### Conexión

# %%
import sys
sys.path.append("..")
import importlib
import active_learning as al
from ultralytics import YOLO
importlib.reload(al)


PROJECT_NAME = "Football Object Detection"
MODEL_PATH ='/home/adrian/IA-Futbol/object_detection/models/train5/weights/best.pt'
MODEL_NAME = "Train5"
model = YOLO(MODEL_PATH)

ls = al.LS(project_name=PROJECT_NAME,model=model,model_name=MODEL_NAME)
# Out:
# verify:True
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 14
#      11 MODEL_NAME = "Train5"
#      12 model = YOLO(MODEL_PATH)
# ---> 14 ls = al.LS(project_name=PROJECT_NAME,model=model,model_name=MODEL_NAME)
#
# File ~/IA-Futbol/dataset_engineering/active_learning/object_detection/../active_learning.py:45, in LS.__init__(self, project_name, model, model_name)
#      43 projects_info = self.client.projects.list()
#      44 self.project = next((p for p in projects_info if p.title == project_name),None)
# ---> 45 self.project = self.client.projects.get(self.project.id)
#
# AttributeError: 'NoneType' object has no attribute 'id'

# %% [markdown]
# ### Sincronizar Imagenes No Etiquetadas

# %%
#Importar imagenes nuevas
ls.import_imgs()

# %%
#sincronizar imagenes
ls.sync_imgs()

# %% [markdown]
# ### Editar Carpeta Imagenes No Etiquetadas

# %%
#elimina tarea e imagen
ls.delete_task(t_id = 19520)

# %% [markdown]
# ### Modelo De Detección y Predicción

# %%
#Predecir las tareas con el modelo
ls.predict_tasks()
# Out:
# 2it [00:00,  2.39it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 #Predecir las tareas con el modelo
# ----> 2 ls.predict_tasks()
#
# File ~/IA-Futbol/dataset_engineering/active_learning/object_detection/../active_learning.py:195, in LS.predict_tasks(self)
#     192 t_properties = task.dict()
#     194 if t_properties['completed_at'] is None: #Solo predecir sobre imagens que no esten completadas
# --> 195     self.annotate_image(t_id= int(t_properties['id']))
#
# File ~/IA-Futbol/dataset_engineering/active_learning/object_detection/../active_learning.py:181, in LS.annotate_image(self, t_id)
#     179 image = Image.open(request.raw)
#     180 w,h = image.size
# --> 181 predictions = self.predict_image(image,w,h)[0]
#     182 self.client.predictions.create(task=task.id, result=predictions['result'], score=float(predictions['score']), model_version=predictions['model_version'])
#
# File ~/IA-Futbol/dataset_engineering/active_learning/object_detection/../active_learning.py:128, in LS.predict_image(self, image, img_width, img_height)
#      96 def predict_image(self,image,img_width,img_height):
#      97     """
#      98     Realiza predicciones sobre una imagen usando el modelo.
#      99
#    (...)    125
#     126     """
# --> 128     results = self.model(image,verbose = False)
#     129     predictions = []
#     130     for result in results:
#
# File ~/anaconda3/envs/IA-Futbol/lib/python3.12/site-packages/ultralytics/engine/model.py:185, in Model.__call__(self, source, stream, **kwargs)
#     156 def __call__(
#     157     self,
#     158     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     159     stream: bool = False,
#     160     **kwargs: Any,
#     161 ) -> list:
#     162     """
#     163     Alias for the predict method, enabling the model instance to be callable for predictions.
#     164
#    (...)    183         ...     print(f"Detected {len(r)} objects in image")
#     184     """
# --> 185     return self.predict(source, stream, **kwargs)
#
# File ~/anaconda3/envs/IA-Futbol/lib/python3.12/site-packages/ultralytics/engine/model.py:555, in Model.predict(self, source, stream, predictor, **kwargs)
#     553 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     554     self.predictor.set_prompts(prompts)
# --> 555 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/anaconda3/envs/IA-Futbol/lib/python3.12/site-packages/ultralytics/engine/predictor.py:227, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     225     return self.stream_inference(source, model, *args, **kwargs)
#     226 else:
# --> 227     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/anaconda3/envs/IA-Futbol/lib/python3.12/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~/anaconda3/envs/IA-Futbol/lib/python3.12/site-packages/ultralytics/engine/predictor.py:329, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     326     im = self.preprocess(im0s)
#     328 # Inference
# --> 329 with profilers[1]:
#     330     preds = self.inference(im, *args, **kwargs)
#     331     if self.args.embed:
#
# File ~/anaconda3/envs/IA-Futbol/lib/python3.12/site-packages/ultralytics/utils/ops.py:61, in Profile.__exit__(self, type, value, traceback)
#      59 def __exit__(self, type, value, traceback):  # noqa
#      60     """Stop timing."""
# ---> 61     self.dt = self.time() - self.start  # delta-time
#      62     self.t += self.dt
#
# File ~/anaconda3/envs/IA-Futbol/lib/python3.12/site-packages/ultralytics/utils/ops.py:71, in Profile.time(self)
#      69 """Get current time with CUDA synchronization if applicable."""
#      70 if self.cuda:
# ---> 71     torch.cuda.synchronize(self.device)
#      72 return time.perf_counter()
#
# File ~/anaconda3/envs/IA-Futbol/lib/python3.12/site-packages/torch/cuda/__init__.py:1040, in synchronize(device)
#    1038 _lazy_init()
#    1039 with torch.cuda.device(device):
# -> 1040     return torch._C._cuda_synchronize()
#
# KeyboardInterrupt:

# %% [markdown]
# ### Ampliar Dataset

# %%
#Generar las etiquetas de las imagenes completadas en la carpeta "completed_tasks"
ls.export_completed_tasks()

# %%
#Copiar las imagenes y las etiquetas de las imagenes completadas al dataset
ls.move2dataset()
# Out:
# 100%|██████████| 154/154 [00:00<00:00, 977.58it/s]
