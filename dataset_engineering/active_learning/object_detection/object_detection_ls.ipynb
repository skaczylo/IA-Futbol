# %%
import sys
sys.path.append("..")
import importlib
import active_learning as al
from ultralytics import YOLO
importlib.reload(al)

MODEL_PATH ='/home/adrian/IA-Futbol/object_detection/models/train5/weights/best.pt'
MODEL_NAME = "Train5"
model = YOLO(MODEL_PATH)

ls = al.LS(project_name="IA-Futbol",model=model,model_name=MODEL_NAME)
# Out:
# verify:True

# %%
ls.import_imgs()

# %%
ls.delete_task(t_id = 40882)

# %%
ls.predict_image(t_id=19234)

# %%
ls.predict_all_tasks()

# %%
ls.predict_new_tasks()

# %%
ls.export_completed_tasks()
# Out:
# Donwload ok
# 100%|██████████| 124/124 [00:00<00:00, 989.51it/s]

# %%
ls.move2dataset()
# Out:
# 100%|██████████| 124/124 [00:00<00:00, 1667.02it/s]

# %%
ls.delete_completed_tasks()
