# %%
import sys
sys.path.append("..")
import importlib
import active_learning as al
from ultralytics import YOLO
importlib.reload(al)

MODEL_PATH ='/home/adrian/IA-Futbol/object_detection/models/train3/weights/best.pt'
MODEL_NAME = "Train3"
model = YOLO(MODEL_PATH)

ls = al.LS(project_name="IA-Futbol",model=model,model_name=MODEL_NAME)
# Out:
# verify:True

# %%
ls.import_imgs()

# %%
ls.delete_task(t_id = 21182)
# Out:
# verify:True

# %%
ls.predict_all_tasks()
# Out:
# 15it [00:03,  4.45it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 ls.predict_all_tasks()
#
# File ~/IA-Futbol/dataset_engineering/active_learning/object_detection/../active_learning.py:109, in LS.predict_all_tasks(self)
#     107 w,h = image.size
#     108 predictions = self.predict_img(image,w,h)[0]
# --> 109 self.client.predictions.create(task=task.id, result=predictions['result'], score=float(predictions['score']), model_version=predictions['model_version'])
#
# File ~/anaconda3/envs/IA-Futbol/lib/python3.12/site-packages/label_studio_sdk/predictions/client.py:160, in PredictionsClient.create(self, task, result, score, model_version, request_options)
#      86 def create(
#      87     self,
#      88     *,
#    (...)     93     request_options: typing.Optional[RequestOptions] = None,
#      94 ) -> Prediction:
#      95     """
# ...

# %%
ls.predict_new_tasks()

# %%
ls.export_completed_tasks()
# Out:
# Donwload ok
# 100%|██████████| 78/78 [00:00<00:00, 3787.23it/s]

# %%
ls.move2dataset()
# Out:
# 100%|██████████| 78/78 [00:00<00:00, 954.62it/s]

# %%
ls.delete_completed_tasks()
