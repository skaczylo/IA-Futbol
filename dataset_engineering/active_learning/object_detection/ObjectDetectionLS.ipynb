# %%
import sys
sys.path.append("..")
import importlib
import active_learning as al
from ultralytics import YOLO
importlib.reload(al)

MODEL_PATH ='/home/adrian/IA-Futbol/runs/detect/train3/weights/best.pt'
MODEL_NAME = "Train3"
model = YOLO(MODEL_PATH)

ls = al.LS(project_name="IA-Futbol",model=model,model_name=MODEL_NAME)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       3 import importlib
#       4 import active_learning as al
# ----> 5 from ultralytics import YOLO
#       6 importlib.reload(al)
#       8 MODEL_PATH ='/home/adrian/IA-Futbol/runs/detect/train3/weights/best.pt'
#
# File ~/anaconda3/envs/IA-Futbol/lib/python3.12/site-packages/ultralytics/__init__.py:11
#       8 if not os.environ.get("OMP_NUM_THREADS"):
#       9     os.environ["OMP_NUM_THREADS"] = "1"  # default for reduced CPU utilization during training
# ---> 11 from ultralytics.models import NAS, RTDETR, SAM, YOLO, YOLOE, FastSAM, YOLOWorld
#      12 from ultralytics.utils import ASSETS, SETTINGS
#      13 from ultralytics.utils.checks import check_yolo as checks
#
# File ~/anaconda3/envs/IA-Futbol/lib/python3.12/site-packages/ultralytics/models/__init__.py:3
# ...

# %%
import sys
sys.path.append("..")  # Subir un nivel desde carpeta2

# %%
ls.import_imgs()

# %%
ls.delete_task(t_id = 99176)
# Out:
# verify:True

# %%
ls.predict_all_tasks()
# Out:
# 330it [01:16,  4.94it/s]
# verify:True
# 1528it [06:15,  3.60it/s]
# verify:True
# 2502it [11:16,  2.82it/s]
# verify:True
# 3549it [16:15,  3.63it/s]
# verify:True
# 4608it [21:16,  3.35it/s]
# verify:True
# 5646it [26:16,  3.21it/s]
# verify:True
# 6643it [31:15,  3.18it/s]
# verify:True
# 7636it [36:15,  3.37it/s]
# verify:True
# 8627it [41:15,  3.49it/s]
# verify:True
# 9619it [46:16,  3.20it/s]
# verify:True
# 10618it [51:16,  3.06it/s]
# verify:True
# 11617it [56:15,  3.16it/s]
# verify:True
# 12612it [1:01:16,  3.47it/s]
# verify:True
# 13608it [1:06:15,  3.36it/s]
# verify:True
# 14604it [1:11:15,  3.24it/s]
# verify:True
# 15661it [1:16:15,  3.23it/s]
# verify:True
# 16723it [1:21:16,  3.53it/s]
# verify:True
# 17781it [1:26:16,  3.39it/s]
# verify:True
# 18834it [1:31:16,  3.36it/s]
# verify:True
# 19891it [1:36:15,  3.80it/s]
# verify:True
# 20953it [1:41:16,  3.15it/s]
# verify:True
# 21944it [1:46:15,  3.68it/s]
# verify:True
# 22944it [1:51:16,  3.30it/s]
# verify:True
# ...

# %%
ls.export_completed_tasks()
ls.delete_completed_tasks()
# Out:
# Donwload ok

# %%
ls.delete_completed_tasks()

# %%
from ultralytics import YOLO
MODEL_PATH ='/home/adrian/IA-Futbol/runs/detect/train2/weights/best.pt'
MODEL_NAME = "Train2"
model = YOLO(MODEL_PATH)

# %%
model.train(
    data='/home/adrian/IA-Futbol/dataset_engineering/active_learning/fine_tuning/data.yaml',       # Ruta a tu archivo YAML con clases y rutas
    epochs=20,
    imgsz=(640, 1152),
    batch=4,
    device=0,            # GPU = 0, CPU = 'cpu'
    project = "/home/adrian/IA-Futbol/runs/detect"
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.163 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.159 🚀 Python-3.12.11 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6057MiB)
# ...

# %%
ls.delete_completed_tasks()
