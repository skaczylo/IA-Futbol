# %%
import importlib
import extract_frames as ef
import youtube_downloader as yd
importlib.reload(ef)
importlib.reload(yd)
# Out:
# <module 'youtube_downloader' from '/home/adrian/IA-Futbol/dataset_engineering/data_generator/youtube_downloader.py'>

# %%
import os
print(os.getcwd())  # Muestra el directorio actual donde Python busca archivos relativos
# Out:
# /home/adrian/IA-Futbol/dataset_engineering/data_generator

# %%
#Descargamos el video o los videos indicamos en urls.txt
urls_path = "urls.txt"

with open(urls_path,"r") as file:
    urls  = file.readlines()

    for url in urls:
        preferred_quality ="1080p"
        yd.download_video(url, preferred_quality)
# Out:
# Fetching video information...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=wwcmm9NNLUM&pp=ygUhZXNwYcOxYSBzZWxlY2Npb24gZnV0Ym9sIGNvbXBsZXRv
#
# [youtube] wwcmm9NNLUM: Downloading webpage
# [youtube] wwcmm9NNLUM: Downloading tv client config
# [youtube] wwcmm9NNLUM: Downloading tv player API JSON
# [youtube] wwcmm9NNLUM: Downloading ios player API JSON
# WARNING: [youtube] wwcmm9NNLUM: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] wwcmm9NNLUM: Downloading m3u8 information
# [info] Testing format 616
# [info] Testing format 234
#
# Video Title: RESUMEN | España 6-5 Alemania | Semifinal | Europeo sub-19 | 🔴 SEFUTBOL
# Duration: 3:40
#
# Available qualities:
# 1. 27p
# 2. 45p
# 3. 90p
# 4. 144p
# 5. 180p
# 6. 240p
# 7. 360p
# 8. 480p
# 9. 720p
# 10. 1080p
#
# Downloading video in 1080p...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=wwcmm9NNLUM&pp=ygUhZXNwYcOxYSBzZWxlY2Npb24gZnV0Ym9sIGNvbXBsZXRv
#
# [youtube] wwcmm9NNLUM: Downloading webpage
# [youtube] wwcmm9NNLUM: Downloading tv client config
# [youtube] wwcmm9NNLUM: Downloading tv player API JSON
# [youtube] wwcmm9NNLUM: Downloading ios player API JSON
# [youtube] wwcmm9NNLUM: Downloading m3u8 information
# [info] wwcmm9NNLUM: Downloading 1 format(s): 137+140
# [download] Destination: videos/RESUMEN ｜ España 6-5 Alemania ｜ Semifinal ｜ Europeo sub-19 ｜ 🔴 SEFUTBOL.f137.mp4
# [download] 100% of  103.11MiB in 00:00:06 at 15.13MiB/s
# [download] Destination: videos/RESUMEN ｜ España 6-5 Alemania ｜ Semifinal ｜ Europeo sub-19 ｜ 🔴 SEFUTBOL.f140.m4a
# [download] 100% of    3.40MiB in 00:00:00 at 7.16MiB/s
# [Merger] Merging formats into "videos/RESUMEN ｜ España 6-5 Alemania ｜ Semifinal ｜ Europeo sub-19 ｜ 🔴 SEFUTBOL.mp4"
# Deleting original file videos/RESUMEN ｜ España 6-5 Alemania ｜ Semifinal ｜ Europeo sub-19 ｜ 🔴 SEFUTBOL.f137.mp4 (pass -k to keep)
# Deleting original file videos/RESUMEN ｜ España 6-5 Alemania ｜ Semifinal ｜ Europeo sub-19 ｜ 🔴 SEFUTBOL.f140.m4a (pass -k to keep)
#
# Download completed successfully!
# Fetching video information...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=E5zEIrabX_A&pp=0gcJCa0JAYcqIYzv
#
# [youtube] E5zEIrabX_A: Downloading webpage
# [youtube] E5zEIrabX_A: Downloading tv client config
# [youtube] E5zEIrabX_A: Downloading tv player API JSON
# [youtube] E5zEIrabX_A: Downloading ios player API JSON
# WARNING: [youtube] E5zEIrabX_A: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] E5zEIrabX_A: Downloading m3u8 information
# [info] Testing format 616
# [info] Testing format 234
#
# Video Title: ON ITS HEAD! | Stoke City v Derby County extended highlights
# Duration: 10:27
#
# Available qualities:
# 1. 27p
# 2. 45p
# 3. 90p
# 4. 144p
# 5. 180p
# 6. 240p
# 7. 360p
# 8. 480p
# 9. 720p
# 10. 1080p
#
# Downloading video in 1080p...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=E5zEIrabX_A&pp=0gcJCa0JAYcqIYzv
#
# [youtube] E5zEIrabX_A: Downloading webpage
# [youtube] E5zEIrabX_A: Downloading tv client config
# [youtube] E5zEIrabX_A: Downloading tv player API JSON
# [youtube] E5zEIrabX_A: Downloading ios player API JSON
# WARNING: [youtube] E5zEIrabX_A: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] E5zEIrabX_A: Downloading m3u8 information
# [info] Testing format 270
# [info] E5zEIrabX_A: Downloading 1 format(s): 18
# [download] Destination: videos/ON ITS HEAD! ｜ Stoke City v Derby County extended highlights.mp4
# [download] 100% of   53.95MiB in 00:00:04 at 11.87MiB/s
#
# Download completed successfully!
# Fetching video information...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zuozAUlV-a4
#
# [youtube] zuozAUlV-a4: Downloading webpage
# [youtube] zuozAUlV-a4: Downloading tv client config
# [youtube] zuozAUlV-a4: Downloading tv player API JSON
# [youtube] zuozAUlV-a4: Downloading ios player API JSON
# [youtube] zuozAUlV-a4: Downloading m3u8 information
# [info] Testing format 616
#
# Video Title: SHOCK WIN! | Sheffield Untied v Bristol City extended highlights
# Duration: 13:04
#
# Available qualities:
# 1. 27p
# 2. 45p
# 3. 90p
# 4. 144p
# 5. 180p
# 6. 240p
# 7. 360p
# 8. 480p
# 9. 720p
# 10. 1080p
#
# Downloading video in 1080p...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zuozAUlV-a4
#
# [youtube] zuozAUlV-a4: Downloading webpage
# [youtube] zuozAUlV-a4: Downloading tv client config
# [youtube] zuozAUlV-a4: Downloading tv player API JSON
# [youtube] zuozAUlV-a4: Downloading ios player API JSON
# WARNING: [youtube] zuozAUlV-a4: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] zuozAUlV-a4: Downloading m3u8 information
# [info] Testing format 270
# [info] zuozAUlV-a4: Downloading 1 format(s): 18
# [download] Destination: videos/SHOCK WIN! ｜ Sheffield Untied v Bristol City extended highlights.mp4
# [download] 100% of   66.88MiB in 00:00:06 at 11.00MiB/s
#
# Download completed successfully!
# Fetching video information...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=e3ppVt7cjjY
#
# [youtube] e3ppVt7cjjY: Downloading webpage
# [youtube] e3ppVt7cjjY: Downloading tv client config
# [youtube] e3ppVt7cjjY: Downloading tv player API JSON
# [youtube] e3ppVt7cjjY: Downloading ios player API JSON
# [youtube] e3ppVt7cjjY: Downloading m3u8 information
# [info] Testing format 616
#
# Video Title: MAY OFF THE MARK! | Huddersfield Town v Leyton Orient extended highlights
# Duration: 11:24
#
# Available qualities:
# 1. 27p
# 2. 45p
# 3. 90p
# 4. 144p
# 5. 180p
# 6. 240p
# 7. 360p
# 8. 480p
# 9. 720p
# 10. 1080p
#
# Downloading video in 1080p...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=e3ppVt7cjjY
#
# [youtube] e3ppVt7cjjY: Downloading webpage
# [youtube] e3ppVt7cjjY: Downloading tv client config
# [youtube] e3ppVt7cjjY: Downloading tv player API JSON
# [youtube] e3ppVt7cjjY: Downloading ios player API JSON
# WARNING: [youtube] e3ppVt7cjjY: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] e3ppVt7cjjY: Downloading m3u8 information
# [info] Testing format 270
# [info] e3ppVt7cjjY: Downloading 1 format(s): 18
# [download] Destination: videos/MAY OFF THE MARK! ｜ Huddersfield Town v Leyton Orient extended highlights.mp4
# [download] 100% of   57.27MiB in 00:00:14 at 3.94MiB/s
#
# Download completed successfully!
# Fetching video information...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6IJJ2faF1a4
#
# [youtube] 6IJJ2faF1a4: Downloading webpage
# [youtube] 6IJJ2faF1a4: Downloading tv client config
# [youtube] 6IJJ2faF1a4: Downloading player 6ea06c52-main
# [youtube] 6IJJ2faF1a4: Downloading tv player API JSON
# [youtube] 6IJJ2faF1a4: Downloading ios player API JSON
# WARNING: [youtube] 6IJJ2faF1a4: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] 6IJJ2faF1a4: Downloading m3u8 information
# [info] Testing format 616
# [info] Testing format 234
#
# Video Title: TITLE DECIDER | Plymouth Argyle v Leeds United in full
# Duration: 152:55
#
# Available qualities:
# 1. 27p
# 2. 45p
# 3. 90p
# 4. 144p
# 5. 180p
# 6. 240p
# 7. 360p
# 8. 480p
# 9. 720p
# 10. 1080p
#
# Downloading video in 1080p...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6IJJ2faF1a4
#
# [youtube] 6IJJ2faF1a4: Downloading webpage
# [youtube] 6IJJ2faF1a4: Downloading tv client config
# [youtube] 6IJJ2faF1a4: Downloading tv player API JSON
# [youtube] 6IJJ2faF1a4: Downloading ios player API JSON
# [youtube] 6IJJ2faF1a4: Downloading m3u8 information
# [info] 6IJJ2faF1a4: Downloading 1 format(s): 137+140
# [download] Destination: videos/TITLE DECIDER ｜ Plymouth Argyle v Leeds United in full.f137.mp4
# [download] 100% of    3.76GiB in 00:04:39 at 13.79MiB/s
# [download] Destination: videos/TITLE DECIDER ｜ Plymouth Argyle v Leeds United in full.f140.m4a
# [download] 100% of  141.61MiB in 00:00:17 at 8.22MiB/s
# [Merger] Merging formats into "videos/TITLE DECIDER ｜ Plymouth Argyle v Leeds United in full.mp4"
# Deleting original file videos/TITLE DECIDER ｜ Plymouth Argyle v Leeds United in full.f140.m4a (pass -k to keep)
# Deleting original file videos/TITLE DECIDER ｜ Plymouth Argyle v Leeds United in full.f137.mp4 (pass -k to keep)
#
# Download completed successfully!
# Fetching video information...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hhQ16xYNMLQ&pp=0gcJCa0JAYcqIYzv
#
# [youtube] hhQ16xYNMLQ: Downloading webpage
# [youtube] hhQ16xYNMLQ: Downloading tv client config
# [youtube] hhQ16xYNMLQ: Downloading tv player API JSON
# [youtube] hhQ16xYNMLQ: Downloading ios player API JSON
# WARNING: [youtube] hhQ16xYNMLQ: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] hhQ16xYNMLQ: Downloading m3u8 information
# [info] Testing format 616
# [info] Testing format 234
#
# Video Title: DONS BOOK WEMBLEY! | AFC Wimbledon v Notts County extended highlights
# Duration: 10:48
#
# Available qualities:
# 1. 27p
# 2. 45p
# 3. 90p
# 4. 144p
# 5. 180p
# 6. 240p
# 7. 360p
# 8. 480p
# 9. 720p
# 10. 1080p
#
# Downloading video in 1080p...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hhQ16xYNMLQ&pp=0gcJCa0JAYcqIYzv
#
# [youtube] hhQ16xYNMLQ: Downloading webpage
# [youtube] hhQ16xYNMLQ: Downloading tv client config
# [youtube] hhQ16xYNMLQ: Downloading tv player API JSON
# [youtube] hhQ16xYNMLQ: Downloading ios player API JSON
# [youtube] hhQ16xYNMLQ: Downloading m3u8 information
# [info] hhQ16xYNMLQ: Downloading 1 format(s): 137+140
# [download] Destination: videos/DONS BOOK WEMBLEY! ｜ AFC Wimbledon v Notts County extended highlights.f137.mp4
# [download] 100% of  249.24MiB in 00:00:33 at 7.37MiB/s
# [download] Destination: videos/DONS BOOK WEMBLEY! ｜ AFC Wimbledon v Notts County extended highlights.f140.m4a
# [download] 100% of   10.01MiB in 00:00:01 at 6.21MiB/s
# [Merger] Merging formats into "videos/DONS BOOK WEMBLEY! ｜ AFC Wimbledon v Notts County extended highlights.mp4"
# Deleting original file videos/DONS BOOK WEMBLEY! ｜ AFC Wimbledon v Notts County extended highlights.f137.mp4 (pass -k to keep)
# Deleting original file videos/DONS BOOK WEMBLEY! ｜ AFC Wimbledon v Notts County extended highlights.f140.m4a (pass -k to keep)
#
# Download completed successfully!
# Fetching video information...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=S14f7oPSFF8
#
# [youtube] S14f7oPSFF8: Downloading webpage
# [youtube] S14f7oPSFF8: Downloading tv client config
# [youtube] S14f7oPSFF8: Downloading tv player API JSON
# [youtube] S14f7oPSFF8: Downloading ios player API JSON
# WARNING: [youtube] S14f7oPSFF8: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] S14f7oPSFF8: Downloading m3u8 information
# [info] Testing format 616
# [info] Testing format 234
#
# Video Title: 🤯 MAD SCENES | Sunderland v Coventry City extended highlights
# Duration: 13:38
#
# Available qualities:
# 1. 27p
# 2. 45p
# 3. 90p
# 4. 144p
# 5. 180p
# 6. 240p
# 7. 360p
# 8. 480p
# 9. 720p
# 10. 1080p
#
# Downloading video in 1080p...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=S14f7oPSFF8
#
# [youtube] S14f7oPSFF8: Downloading webpage
# [youtube] S14f7oPSFF8: Downloading tv client config
# [youtube] S14f7oPSFF8: Downloading tv player API JSON
# [youtube] S14f7oPSFF8: Downloading ios player API JSON
# WARNING: [youtube] S14f7oPSFF8: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] S14f7oPSFF8: Downloading m3u8 information
# [info] Testing format 270
# [info] S14f7oPSFF8: Downloading 1 format(s): 18
# [download] Destination: videos/🤯 MAD SCENES ｜ Sunderland v Coventry City extended highlights.mp4
# [download] 100% of   66.47MiB in 00:00:25 at 2.61MiB/s
#
# Download completed successfully!
# Fetching video information...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UMNEYNBwaRA
#
# [youtube] UMNEYNBwaRA: Downloading webpage
# [youtube] UMNEYNBwaRA: Downloading tv client config
# [youtube] UMNEYNBwaRA: Downloading tv player API JSON
# [youtube] UMNEYNBwaRA: Downloading ios player API JSON
# [youtube] UMNEYNBwaRA: Downloading m3u8 information
#
# Video Title: Luton Town v Coventry City Highlights
# Duration: 2:21
#
# Available qualities:
# 1. 27p
# 2. 45p
# 3. 90p
# 4. 144p
# 5. 180p
# 6. 240p
# 7. 360p
# 8. 480p
# 9. 720p
# 10. 1080p
#
# Downloading video in 1080p...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UMNEYNBwaRA
#
# [youtube] UMNEYNBwaRA: Downloading webpage
# [youtube] UMNEYNBwaRA: Downloading tv client config
# [youtube] UMNEYNBwaRA: Downloading tv player API JSON
# [youtube] UMNEYNBwaRA: Downloading ios player API JSON
# [youtube] UMNEYNBwaRA: Downloading m3u8 information
# [info] UMNEYNBwaRA: Downloading 1 format(s): 137+140
# [download] Destination: videos/Luton Town v Coventry City Highlights.f137.mp4
# [download] 100% of   63.04MiB in 00:00:13 at 4.69MiB/s
# [download] Destination: videos/Luton Town v Coventry City Highlights.f140.m4a
# [download] 100% of    2.17MiB in 00:00:00 at 4.10MiB/s
# [Merger] Merging formats into "videos/Luton Town v Coventry City Highlights.mp4"
# Deleting original file videos/Luton Town v Coventry City Highlights.f137.mp4 (pass -k to keep)
# Deleting original file videos/Luton Town v Coventry City Highlights.f140.m4a (pass -k to keep)
#
# Download completed successfully!
# Fetching video information...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1xnCDGbR9gM
#
# [youtube] 1xnCDGbR9gM: Downloading webpage
# [youtube] 1xnCDGbR9gM: Downloading tv client config
# [youtube] 1xnCDGbR9gM: Downloading tv player API JSON
# [youtube] 1xnCDGbR9gM: Downloading ios player API JSON
# WARNING: [youtube] 1xnCDGbR9gM: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] 1xnCDGbR9gM: Downloading m3u8 information
# [info] Testing format 616
# [info] Testing format 234
#
# Video Title: OUT OF TOP 2! | Wycombe Wanderers v Charlton Athletic extended highlights
# Duration: 11:04
#
# Available qualities:
# 1. 27p
# 2. 45p
# 3. 90p
# 4. 144p
# 5. 180p
# 6. 240p
# 7. 360p
# 8. 480p
# 9. 720p
# 10. 1080p
#
# Downloading video in 1080p...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1xnCDGbR9gM
#
# [youtube] 1xnCDGbR9gM: Downloading webpage
# [youtube] 1xnCDGbR9gM: Downloading tv client config
# [youtube] 1xnCDGbR9gM: Downloading tv player API JSON
# [youtube] 1xnCDGbR9gM: Downloading ios player API JSON
# [youtube] 1xnCDGbR9gM: Downloading m3u8 information
# [info] 1xnCDGbR9gM: Downloading 1 format(s): 137+140
# [download] Destination: videos/OUT OF TOP 2! ｜ Wycombe Wanderers v Charlton Athletic extended highlights.f137.mp4
# [download] 100% of  293.15MiB in 00:01:18 at 3.72MiB/s
# [download] Destination: videos/OUT OF TOP 2! ｜ Wycombe Wanderers v Charlton Athletic extended highlights.f140.m4a
# [download] 100% of   10.24MiB in 00:00:01 at 6.90MiB/s
# [Merger] Merging formats into "videos/OUT OF TOP 2! ｜ Wycombe Wanderers v Charlton Athletic extended highlights.mp4"
# Deleting original file videos/OUT OF TOP 2! ｜ Wycombe Wanderers v Charlton Athletic extended highlights.f137.mp4 (pass -k to keep)
# Deleting original file videos/OUT OF TOP 2! ｜ Wycombe Wanderers v Charlton Athletic extended highlights.f140.m4a (pass -k to keep)
#
# Download completed successfully!
# Fetching video information...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Iwg4ABPW1nk
# [youtube] Iwg4ABPW1nk: Downloading webpage
# [youtube] Iwg4ABPW1nk: Downloading tv client config
# [youtube] Iwg4ABPW1nk: Downloading tv player API JSON
# [youtube] Iwg4ABPW1nk: Downloading ios player API JSON
# WARNING: [youtube] Iwg4ABPW1nk: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] Iwg4ABPW1nk: Downloading m3u8 information
# [info] Testing format 614
# [info] Testing format 234
#
# Video Title: 5 CLEAR OF 3RD! | Leeds Untied v Preston North End extended highlights
# Duration: 11:22
#
# Available qualities:
# 1. 27p
# 2. 45p
# 3. 90p
# 4. 144p
# 5. 180p
# 6. 240p
# 7. 360p
# 8. 480p
# 9. 720p
# 10. 1080p
#
# Downloading video in 1080p...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Iwg4ABPW1nk
# [youtube] Iwg4ABPW1nk: Downloading webpage
# [youtube] Iwg4ABPW1nk: Downloading tv client config
# [youtube] Iwg4ABPW1nk: Downloading tv player API JSON
# [youtube] Iwg4ABPW1nk: Downloading ios player API JSON
# [youtube] Iwg4ABPW1nk: Downloading m3u8 information
# [info] Iwg4ABPW1nk: Downloading 1 format(s): 137+140
# [download] Destination: videos/5 CLEAR OF 3RD! ｜ Leeds Untied v Preston North End extended highlights.f137.mp4
# [download] 100% of  361.68MiB in 00:00:50 at 7.12MiB/s
# [download] Destination: videos/5 CLEAR OF 3RD! ｜ Leeds Untied v Preston North End extended highlights.f140.m4a
# [download] 100% of   10.53MiB in 00:00:02 at 5.20MiB/s
# [Merger] Merging formats into "videos/5 CLEAR OF 3RD! ｜ Leeds Untied v Preston North End extended highlights.mp4"
# Deleting original file videos/5 CLEAR OF 3RD! ｜ Leeds Untied v Preston North End extended highlights.f137.mp4 (pass -k to keep)
# Deleting original file videos/5 CLEAR OF 3RD! ｜ Leeds Untied v Preston North End extended highlights.f140.m4a (pass -k to keep)
#
# Download completed successfully!

# %%
videos_path = "videos"

videos_names = os.listdir(videos_path)

for video_name in videos_names:
    ef.extract_frames(os.path.join(videos_path,video_name),output_path="generated_images",percentage=0.3,delete=True)
# Out:
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37858980] mmco: unref short failure
# [h264 @ 0x37b53c80] mmco: unref short failure
# [h264 @ 0x37b53c80] mmco: unref short failure
# [h264 @ 0x37b53c80] mmco: unref short failure
# [h264 @ 0x37b53c80] mmco: unref short failure
# [h264 @ 0x37843640] mmco: unref short failure
# [h264 @ 0x37843640] mmco: unref short failure
# [h264 @ 0x37843640] mmco: unref short failure
# [h264 @ 0x37843640] mmco: unref short failure
# [h264 @ 0x37843640] mmco: unref short failure
# [h264 @ 0x37843640] mmco: unref short failure
# [h264 @ 0x37843640] mmco: unref short failure
# [h264 @ 0x37843640] mmco: unref short failure
# [h264 @ 0x37843640] mmco: unref short failure
