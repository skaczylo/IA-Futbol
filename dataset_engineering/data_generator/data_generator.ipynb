# %%
import importlib
import extract_frames as ef
import youtube_downloader as yd
importlib.reload(ef)
importlib.reload(yd)
# Out:
# <module 'youtube_downloader' from '/home/adrian/IA-Futbol/dataset_engineering/data_generator/youtube_downloader.py'>

# %%
import os
print(os.getcwd())  # Muestra el directorio actual donde Python busca archivos relativos
# Out:
# /home/adrian/IA-Futbol/dataset_engineering/data_generator

# %%
#Descargamos el video o los videos indicamos en urls.txt
urls_path = "urls.txt"

with open(urls_path,"r") as file:
    urls  = file.readlines()

    for url in urls:
        preferred_quality ="1080p"
        yd.download_video(url, preferred_quality)
# Out:
# Fetching video information...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=B_rWyxENQN4
# [youtube] B_rWyxENQN4: Downloading webpage
# [youtube] B_rWyxENQN4: Downloading tv client config
# [youtube] B_rWyxENQN4: Downloading tv player API JSON
# [youtube] B_rWyxENQN4: Downloading ios player API JSON
# [youtube] B_rWyxENQN4: Downloading m3u8 information
# [info] Testing format 616
#
# Video Title: Resumen España - Bélgica (6-2) | UEFA Women’s EURO 2025™
# Duration: 4:34
#
# Available qualities:
# 1. 27p
# 2. 45p
# 3. 90p
# 4. 144p
# 5. 180p
# 6. 240p
# 7. 360p
# 8. 480p
# 9. 720p
# 10. 1080p
#
# Downloading video in 1080p...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=B_rWyxENQN4
# [youtube] B_rWyxENQN4: Downloading webpage
# [youtube] B_rWyxENQN4: Downloading tv client config
# [youtube] B_rWyxENQN4: Downloading tv player API JSON
# [youtube] B_rWyxENQN4: Downloading ios player API JSON
# [youtube] B_rWyxENQN4: Downloading m3u8 information
# [info] B_rWyxENQN4: Downloading 1 format(s): 137+140
# [download] Destination: videos/Resumen España - Bélgica (6-2) ｜ UEFA Women’s EURO 2025™.f137.mp4
# [download] 100% of  130.65MiB in 00:00:07 at 16.49MiB/s
# [download] Destination: videos/Resumen España - Bélgica (6-2) ｜ UEFA Women’s EURO 2025™.f140.m4a
# [download] 100% of    4.23MiB in 00:00:00 at 10.73MiB/s
# [Merger] Merging formats into "videos/Resumen España - Bélgica (6-2) ｜ UEFA Women’s EURO 2025™.mp4"
# Deleting original file videos/Resumen España - Bélgica (6-2) ｜ UEFA Women’s EURO 2025™.f137.mp4 (pass -k to keep)
# Deleting original file videos/Resumen España - Bélgica (6-2) ｜ UEFA Women’s EURO 2025™.f140.m4a (pass -k to keep)
#
# Download completed successfully!

# %%
videos_path = "videos"

videos_names = os.listdir(videos_path)

for video_name in videos_names:
    ef.extract_frames(os.path.join(videos_path,video_name),output_path="generated_images",percentage=0.4,delete=True)
